# %%
import os
import sqlalchemy
from sqlalchemy import create_engine

# ----------------------------------------------------------------------------
# Database engine configuration
# ----------------------------------------------------------------------------
# Update the connection string below to match your local or remote Postgres instance.
from pydotenv import Environment
env = Environment('.env')

# Current local test engine (edit as needed):
engine = create_engine(f'postgresql://{env.get('DB_USER')}:{env.get('DB_PASS')}@{env.get('DB_HOST')}:{env.get('DB_PORT')}/{env.get('DB_NAME')}')
engine  # display engine info to confirm connection string format

# %%
from typing import List, Optional
from sqlalchemy import ForeignKey, String
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, relationship

class Base(DeclarativeBase):
    pass

# %%
class Cars45(Base):
    __tablename__ = "cars45"

    car_id: Mapped[str] = mapped_column(primary_key=True)
    description: Mapped[str]
    amount: Mapped[int]
    region: Mapped[str]
    make: Mapped[str]
    model: Mapped[str]
    year_of_man: Mapped[int]
    color: Mapped[str]
    condition: Mapped[str]
    mileage: Mapped[int]
    engine_size: Mapped[int]
    selling_cond: Mapped[str]
    bought_cond: Mapped[str]
    trim: Mapped[str]
    drive_train: Mapped[str]
    reg_city: Mapped[str]
    seat: Mapped[str]
    num_cylinder: Mapped[int]
    horse_power: Mapped[int]
    body_build: Mapped[str]
    fuel_type: Mapped[str]
    transmission: Mapped[str]

# %%
import pandas as pd

df = pd.read_csv("./sources/car45_data.csv", index_col=0)

# %%
df.head()
# Out:
#                      car_id                        description    amount  \
# 0  5IQTDBTYmvK1tJwhdvGJfESJ          Lexus ES 350 FWD 2013 Red  12937500
# 1  zpZUGomoVXuKk9UFa8j8moC9  Land Rover Range Rover 2012 White   6750000
# 2  a6ShZXOX4KtY6IBGJIcF3Cxk          Toyota Sequoia 2018 Black  50625000
# 3  CciPNDN6vhhQQI1FTQHAbfxi          Toyota Corolla 2007 Green   3600000
# 4  bvwd5LDMx6mIYpVa6Uhi2jqJ  Mercedes-Benz M Class 2005 Silver   3262500
#
#                         region           make        model  year_of_man  \
# 0           Lagos State, Ikeja          Lexus           ES         2013
# 1         Abuja (FCT), Garki 2     Land Rover  Range Rover         2012
# 2           Lagos State, Lekki         Toyota      Sequoia         2018
# 3  Abuja (FCT), Lugbe District         Toyota      Corolla         2007
# 4           Lagos State, Isolo  Mercedes-Benz      M Class         2005
#
#     color      condition   mileage  ...  bought_cond     trim  drive_train  \
# 0     Red   Foreign Used  272474.0  ...     Imported  350 FWD  Front Wheel
# 1   White  Nigerian Used  102281.0  ...   Registered      NaN          NaN
# 2   Black   Foreign Used  127390.0  ...     Imported      NaN          NaN
# 3   Green  Nigerian Used  139680.0  ...   Registered      NaN          NaN
# 4  Silver  Nigerian Used  220615.0  ...     Imported      NaN          NaN
#
#   reg_city seat num_cylinder horse_power  body_build  fuel_type transmission
# 0      NaN    5          6.0       268.0       Sedan     Petrol    Automatic
# 1      NaN  NaN          NaN         NaN         SUV     Petrol    Automatic
# 2      NaN  NaN          NaN         NaN         SUV     Petrol    Automatic
# 3    ABUJA  NaN          NaN         NaN         NaN     Petrol    Automatic
# 4    ABUJA  NaN          NaN         NaN         NaN     Petrol    Automatic
#
# [5 rows x 22 columns]

# %%
string_columns = [col for col in df.columns if df.dtypes[col] == 'O']
string_columns.remove('seat')
df[string_columns] = df[string_columns].fillna('unknown')

df[string_columns].sample(5)
# Out:
#                         car_id              description  \
# 250   cLu7fU4qZvkR4YiBFkc7d3Mw  Lexus RX 350 2011 Black
# 3828  fwi9j28u4b3n4FgLyMwiPXX5    Mazda CX-9 2009 Black
# 3044  anVA3v42vCT63158NuNwShQU  Toyota Sienna 2014 Blue
# 907   Cp3QOLqL8obO1eDcAhZ3wEBD        Audi A4 2006 Blue
# 3497  8Z4fcPTP321ZuYCfknUOQYd0  Toyota Camry 2009 Green
#
#                          region    make   model  color      condition  \
# 250          Lagos State, Lekki   Lexus  RX 350  Black   Foreign Used
# 3828  Lagos State, Amuwo-Odofin   Mazda    CX-9  Black   Foreign Used
# 3044          Ondo State, Akure  Toyota  Sienna   Blue   Foreign Used
# 907           Lagos State, Ajah    Audi      A4   Blue  Nigerian Used
# 3497          Oyo State, Ibadan  Toyota   Camry  Green   Foreign Used
#
#      selling_cond bought_cond                                           trim  \
# 250      Imported    Imported                                        unknown
# 3828     Imported    Imported                                        unknown
# 3044     Imported    Imported  LE 7-Passenger 4dr Minivan AWD (3.5L 6cyl 6A)
# 907    Registered  Registered                                        unknown
# 3497     Imported    Imported                                        unknown
#
#      drive_train reg_city body_build fuel_type transmission
# 250      unknown  unknown        SUV    Petrol    Automatic
# 3828     unknown  unknown        SUV    Petrol    Automatic
# 3044   All Wheel  unknown    Minivan    Petrol    Automatic
# 907      unknown    Lagos    unknown    Petrol    Automatic
# 3497     unknown  unknown    unknown    Petrol    Automatic

# %%
num_columns = list(set(df.columns) - {col for col in df.columns if df.dtypes[col] == 'O'})
df[num_columns] = df[num_columns].fillna(0)

df[num_columns].sample(5)
# Out:
#       engine_size  year_of_man   mileage  num_cylinder  horse_power   amount
# 1001       2200.0         2005  176791.0           0.0          0.0  2520000
# 971        1800.0         2010  139161.0           0.0          0.0  4160000
# 3972       2200.0         1999  275680.0           0.0          0.0  1092000
# 1217       3500.0         2007  121586.0           0.0          0.0  4784000
# 3227       3500.0         2008  106331.0           6.0          0.0  4368000

# %%
df.seat.fillna("0", inplace=True)
df.seat.sample(5)
# Out:
# 3264    0
# 709     0
# 152     0
# 692     0
# 988     5
# Name: seat, dtype: object

# %%
df.describe()
# Out:
#              amount  year_of_man       mileage    engine_size  num_cylinder  \
# count  2.894000e+03  2894.000000  2.829000e+03    2846.000000    369.000000
# mean   4.986147e+06  2007.782654  2.433475e+05    3079.524596      5.411924
# std    6.177222e+06     4.565697  1.416721e+06    3753.377371      1.301533
# min    5.775000e+05  1988.000000  0.000000e+00      25.000000      4.000000
# 25%    2.166000e+06  2005.000000  1.300590e+05    2300.000000      4.000000
# 50%    3.203125e+06  2007.000000  1.913980e+05    3000.000000      6.000000
# 75%    5.250000e+06  2011.000000  2.659880e+05    3500.000000      6.000000
# max    9.870000e+07  2023.000000  7.402675e+07  158713.000000      8.000000
#
#        horse_power
# count   338.000000
# mean    216.816568
# std      69.989033
# min      67.000000
# 25%     158.000000
# 50%     225.000000
# 75%     269.750000
# max     477.000000

# %%
Base.metadata.create_all(bind=engine)
# Out:
# 2025-10-04 00:16:16,801 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-10-04 00:16:16,802 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-04 00:16:16,807 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-10-04 00:16:16,808 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-04 00:16:16,814 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-10-04 00:16:16,816 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-04 00:16:16,820 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-04 00:16:16,829 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-10-04 00:16:16,830 INFO sqlalchemy.engine.Engine [generated in 0.00148s] {'table_name': 'cars45', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-10-04 00:16:16,843 INFO sqlalchemy.engine.Engine
# CREATE TABLE cars45 (
# 	car_id VARCHAR NOT NULL,
# 	description VARCHAR NOT NULL,
# 	amount INTEGER NOT NULL,
# 	region VARCHAR NOT NULL,
# 	make VARCHAR NOT NULL,
# 	model VARCHAR NOT NULL,
# 	year_of_man INTEGER NOT NULL,
# 	color VARCHAR NOT NULL,
# 	condition VARCHAR NOT NULL,
# 	mileage INTEGER NOT NULL,
# 	engine_size INTEGER NOT NULL,
# 	selling_cond VARCHAR NOT NULL,
# 	bought_cond VARCHAR NOT NULL,
# 	trim VARCHAR NOT NULL,
# 	drive_train VARCHAR NOT NULL,
# 	reg_city VARCHAR NOT NULL,
# 	seat VARCHAR NOT NULL,
# 	num_cylinder INTEGER NOT NULL,
# 	horse_power INTEGER NOT NULL,
# 	body_build VARCHAR NOT NULL,
# 	fuel_type VARCHAR NOT NULL,
# 	transmission VARCHAR NOT NULL,
# 	PRIMARY KEY (car_id)
# )
#
#
# 2025-10-04 00:16:16,844 INFO sqlalchemy.engine.Engine [no key 0.00122s] {}
# 2025-10-04 00:16:16,888 INFO sqlalchemy.engine.Engine COMMIT

# %%
df.to_csv('./clean_cars45.csv', index=False)

# %%
from csv import DictReader
import csv

store = []

with open("./clean_cars45.csv", newline='') as f:
    # print(f.read())
    source = csv.DictReader(f)
    for record in source:
        store.append(record)

# %%
store
# Out:
# [{'car_id': '5IQTDBTYmvK1tJwhdvGJfESJ',
#   'description': 'Lexus ES 350 FWD 2013 Red',
#   'amount': '12937500',
#   'region': 'Lagos State, Ikeja',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2013',
#   'color': 'Red',
#   'condition': 'Foreign Used',
#   'mileage': '272474.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': '350 FWD',
#   'drive_train': 'Front Wheel',
#   'reg_city': 'unknown',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '268.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zpZUGomoVXuKk9UFa8j8moC9',
#   'description': 'Land Rover Range Rover 2012 White',
#   'amount': '6750000',
#   'region': 'Abuja (FCT), Garki 2',
#   'make': 'Land Rover',
#   'model': 'Range Rover',
#   'year_of_man': '2012',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '102281.0',
#   'engine_size': '5000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'a6ShZXOX4KtY6IBGJIcF3Cxk',
#   'description': 'Toyota Sequoia 2018 Black',
#   'amount': '50625000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Toyota',
#   'model': 'Sequoia',
#   'year_of_man': '2018',
#   'color': 'Black',
#   'condition': 'Foreign Used',
#   'mileage': '127390.0',
#   'engine_size': '5700.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'CciPNDN6vhhQQI1FTQHAbfxi',
#   'description': 'Toyota Corolla 2007 Green',
#   'amount': '3600000',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2007',
#   'color': 'Green',
#   'condition': 'Nigerian Used',
#   'mileage': '139680.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'bvwd5LDMx6mIYpVa6Uhi2jqJ',
#   'description': 'Mercedes-Benz M Class 2005 Silver',
#   'amount': '3262500',
#   'region': 'Lagos State, Isolo',
#   'make': 'Mercedes-Benz',
#   'model': 'M Class',
#   'year_of_man': '2005',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '220615.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'rR9jyMmvS5QYArvQplOQRVid',
#   'description': 'Lexus ES 2007 Blue',
#   'amount': '4837500',
#   'region': 'Abuja (FCT), Gwarinpa',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2007',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '347614.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'hy7yBdW3a3EbwkZU7WGHqUPr',
#   'description': 'Lexus ES 350 2008 White',
#   'amount': '4162500',
#   'region': 'Abuja (FCT), Kubwa',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2008',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '126841.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': '350',
#   'drive_train': 'Front',
#   'reg_city': 'ABUJA',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '0.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'x2Uz0Pm5w43ConBBsmAOQPOV',
#   'description': 'Ford Escape XLS 4x4 2005 Ivory',
#   'amount': '1721250',
#   'region': 'Lagos State, Ikeja',
#   'make': 'Ford',
#   'model': 'Escape',
#   'year_of_man': '2005',
#   'color': 'Ivory',
#   'condition': 'Nigerian Used',
#   'mileage': '246930.0',
#   'engine_size': '3000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'XLS 4x4',
#   'drive_train': 'All Wheel',
#   'reg_city': 'LAGOS',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '156.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'n8PHuxWTdbg0HvvedjTf5CJZ',
#   'description': 'Acura MDX 2011 Blue',
#   'amount': '4590000',
#   'region': 'Lagos State, Ikotun/Igando',
#   'make': 'Acura',
#   'model': 'MDX',
#   'year_of_man': '2011',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '122734.0',
#   'engine_size': '3700.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'xEGLEYM0Nt5xNQJatGMewIVr',
#   'description': 'Toyota Highlander 2015 Teal',
#   'amount': '18000000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Toyota',
#   'model': 'Highlander',
#   'year_of_man': '2015',
#   'color': 'Teal',
#   'condition': 'Nigerian Used',
#   'mileage': '130078.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'C84Q2hN2YYWK4w3efHDl3ye6',
#   'description': 'Toyota Corolla 2010 Blue',
#   'amount': '4500000',
#   'region': 'Lagos State, Ikoyi',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2010',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '74424.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Brand new',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '1stYRXx6y2mQsEOWbHmOArcd',
#   'description': 'Toyota Corolla 2004 Blue',
#   'amount': '3600000',
#   'region': 'Abuja (FCT), Mararaba',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2004',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '175337.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Abuja',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'fp4C6S86mDmiJOL1xDAgOB44',
#   'description': 'Lexus IS 250 AWD 2006 Black',
#   'amount': '2812500',
#   'region': 'Lagos State, Lekki',
#   'make': 'Lexus',
#   'model': 'IS',
#   'year_of_man': '2006',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '259663.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': '250 AWD',
#   'drive_train': 'All Wheel',
#   'reg_city': 'ABUJA',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '208.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'z5jxNPzDkJuMDiWimRVxb99L',
#   'description': 'Toyota Avalon 2013 Black',
#   'amount': '7875000',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Toyota',
#   'model': 'Avalon',
#   'year_of_man': '2013',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '124233.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'kmNj5VyxYaoxl7YbAvM3Bych',
#   'description': 'Toyota Camry 2001 Gray',
#   'amount': '2137500',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2001',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '155469.0',
#   'engine_size': '2200.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'aofdrJ1wmX0QL4gQ2KKVRGwp',
#   'description': 'Land Rover Range Rover 2008 White',
#   'amount': '4303125',
#   'region': 'Lagos State, Ajah',
#   'make': 'Land Rover',
#   'model': 'Range Rover',
#   'year_of_man': '2008',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '144381.0',
#   'engine_size': '4400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'mPa4MnSwhQp4wzOAB8SFudOg',
#   'description': 'Toyota Corolla 2014 Silver',
#   'amount': '6187500',
#   'region': 'Oyo State, Ibadan',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2014',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '101872.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos State',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'Bok4bZ3DUH2NppYYGMHDkQe0',
#   'description': 'Lexus GS 2008 Gray',
#   'amount': '2953125',
#   'region': 'Lagos State, Lekki',
#   'make': 'Lexus',
#   'model': 'GS',
#   'year_of_man': '2008',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '98229.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'kLIpsBxMp7ExegbbzB29OHVN',
#   'description': 'Honda Accord 2010 Black',
#   'amount': '2025000',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2010',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '82091.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'BXSpWEnzV3t9SEkPDLX14Qq6',
#   'description': 'Honda Pilot 2008 White',
#   'amount': '3150000',
#   'region': 'Kwara State, Ilorin East',
#   'make': 'Honda',
#   'model': 'Pilot',
#   'year_of_man': '2008',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '142806.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'iUyhLAvmvgbqQQZzCC261pPR',
#   'description': 'Toyota Corolla 2009 White',
#   'amount': '2812500',
#   'region': 'Lagos State, Amuwo-Odofin',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2009',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '291419.0',
#   'engine_size': '0.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'nhqZPJ6HvZfoeOT9u0mNppQV',
#   'description': 'Lexus GX 2003 Black',
#   'amount': '4050000',
#   'region': 'Lagos State, Amuwo-Odofin',
#   'make': 'Lexus',
#   'model': 'GX',
#   'year_of_man': '2003',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '115676.0',
#   'engine_size': '4700.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'xCKl4TrUzfxyQZUzuxkkttGq',
#   'description': 'BMW 323i 2008 Gray',
#   'amount': '3937500',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'BMW',
#   'model': '323i',
#   'year_of_man': '2008',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '143258.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'KADUNA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'pGdxpP788sdLQXZoNAQYRMlz',
#   'description': 'Toyota Corolla 2006 Gray',
#   'amount': '2925000',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2006',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '299999.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'hyibVSePNRdEPBHpq17Ssnyi',
#   'description': 'Lexus RX 350 2012 Black',
#   'amount': '11250000',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Lexus',
#   'model': 'RX 350',
#   'year_of_man': '2012',
#   'color': 'Black',
#   'condition': 'Foreign Used',
#   'mileage': '160198.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'doklctAs5c90WmafsFgYkfre',
#   'description': 'Lexus GS 2006 Silver',
#   'amount': '3375000',
#   'region': 'Lagos State, Alimosho',
#   'make': 'Lexus',
#   'model': 'GS',
#   'year_of_man': '2006',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '61517.0',
#   'engine_size': '3000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'mCqsgtdzbm1HesNIpQm9iI7J',
#   'description': 'Toyota Corolla 2004 Silver',
#   'amount': '2812500',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2004',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '126158.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'kEb3OtWV7u2bTXpfW7D21pkt',
#   'description': 'Kia Sorento 2011 Gray',
#   'amount': '4500000',
#   'region': 'Rivers State, Port-Harcourt',
#   'make': 'Kia',
#   'model': 'Sorento',
#   'year_of_man': '2011',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '133102.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '3q8SZAdk8ZST1zSzEYqPSABX',
#   'description': 'Volkswagen Golf 1999 Blue',
#   'amount': '843750',
#   'region': 'Delta State, Oshimili South',
#   'make': 'Volkswagen',
#   'model': 'Golf',
#   'year_of_man': '1999',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '171950.0',
#   'engine_size': '1600.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ANAMBRA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'xqpJyDZHGigalYWWclNBTc2X',
#   'description': 'Toyota Camry 2004 Gray',
#   'amount': '2925000',
#   'region': 'Oyo State, Ibadan',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2004',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '412440.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'rsZqHZVva6xZEpPjkDXgyvoS',
#   'description': 'Land Rover Range Rover Evoque Coupe Dynamic 2012 Black',
#   'amount': '8437500',
#   'region': 'Rivers State, Port-Harcourt',
#   'make': 'Land Rover',
#   'model': 'Range Rover Evoque',
#   'year_of_man': '2012',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '75626.0',
#   'engine_size': '2000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'Coupe Dynamic',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'Coupe',
#   'fuel_type': 'Petrol',
#   'transmission': 'AMT'},
#  {'car_id': '1auTrHolJ2CMzONczsc9Rcbv',
#   'description': 'Toyota Corolla 2004 Gold',
#   'amount': '2250000',
#   'region': 'Lagos State, Ikotun/Igando',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2004',
#   'color': 'Gold',
#   'condition': 'Nigerian Used',
#   'mileage': '299999.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'CoFu7yWkhHCIVMj9bYgOMl9l',
#   'description': 'Toyota Camry 2013 Gray',
#   'amount': '6412500',
#   'region': 'Lagos State, Ipaja',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2013',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '119344.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'knfAl9LnCE1Jc1jWtFOyok2s',
#   'description': 'Honda Accord 2009 Silver',
#   'amount': '2587500',
#   'region': 'Lagos State, Alimosho',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2009',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '215154.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'r52kQH02OW3X2puGo3EMWILQ',
#   'description': 'Toyota Corolla 2003 Silver',
#   'amount': '1968750',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2003',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '231251.0',
#   'engine_size': '2800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'Crci3qnqE3YWSxIBodT0Op8v',
#   'description': 'Toyota Camry 2004 Teal',
#   'amount': '2475000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2004',
#   'color': 'Teal',
#   'condition': 'Nigerian Used',
#   'mileage': '189045.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'aEwTZA6nC4y6fwtRwJPjpKCf',
#   'description': 'Acura MDX 2001 Gold',
#   'amount': '1687500',
#   'region': 'Lagos State, Mushin',
#   'make': 'Acura',
#   'model': 'MDX',
#   'year_of_man': '2001',
#   'color': 'Gold',
#   'condition': 'Nigerian Used',
#   'mileage': '367075.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'yR3fyAoT6i3S3HS9S7ukReJc',
#   'description': 'Toyota Camry 2008 Silver',
#   'amount': '2651175',
#   'region': 'Abuja (FCT), Katampe',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2008',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '153565.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '43PvhLRx7YdNnhxIGbzmMe0X',
#   'description': 'Toyota Highlander Base AWD 2002 Red',
#   'amount': '3037500',
#   'region': 'Akwa Ibom State, Uyo',
#   'make': 'Toyota',
#   'model': 'Highlander',
#   'year_of_man': '2002',
#   'color': 'Red',
#   'condition': 'Nigerian Used',
#   'mileage': '244149.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'Base AWD',
#   'drive_train': 'All Wheel',
#   'reg_city': 'ABIA',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '155.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '7AwjbX5q59g7oENyutGETzn5',
#   'description': 'Honda Accord 2003 Gray',
#   'amount': '1237500',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2003',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '121529.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Abuja',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'ByslsTMfVbRv1KJ4drLv5IM3',
#   'description': 'Lexus GX 2015 Black',
#   'amount': '33750000',
#   'region': 'Lagos State, Ikoyi',
#   'make': 'Lexus',
#   'model': 'GX',
#   'year_of_man': '2015',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '62104.0',
#   'engine_size': '4600.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'hsWSpXq6KCvEtbtQBhv9G3zs',
#   'description': 'Lexus ES 2007 Beige',
#   'amount': '3937500',
#   'region': 'Abuja (FCT), Gwarinpa',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2007',
#   'color': 'Beige',
#   'condition': 'Nigerian Used',
#   'mileage': '134172.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '5HTfRXlSfYFQBjhxHIoJuWTr',
#   'description': 'Honda Accord 2009 Silver',
#   'amount': '2385000',
#   'region': 'Lagos State, Surulere',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2009',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '390792.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'wwfQ7AX1qRs5smNSF5f6gpvA',
#   'description': 'Toyota Camry 1998 Silver',
#   'amount': '1012500',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '1998',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '212122.0',
#   'engine_size': '2200.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '7Q8kF5kKNSPJEEWaaStYBk0S',
#   'description': 'Toyota Land Cruiser Prado 2.7 VVT-i 2015 Gray',
#   'amount': '15750000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Toyota',
#   'model': 'Land Cruiser Prado',
#   'year_of_man': '2015',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '47395.0',
#   'engine_size': '2700.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': '2.7 VVT-i',
#   'drive_train': 'All Wheel',
#   'reg_city': 'LAGOS',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '163.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zhsL7a37tGYeTflkHjMrsTPh',
#   'description': 'Lexus IS 2008 Black',
#   'amount': '5400000',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Lexus',
#   'model': 'IS',
#   'year_of_man': '2008',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '104166.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zxdAn3OJgSIpIKoNak6fLB9b',
#   'description': 'Lexus ES 2007 Black',
#   'amount': '4303125',
#   'region': 'Abuja (FCT), Katampe',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2007',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '160987.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'r4CcY7dofjTttJQt7lvhPDCp',
#   'description': 'Honda Civic 2007 Gray',
#   'amount': '2250000',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Honda',
#   'model': 'Civic',
#   'year_of_man': '2007',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '199805.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '4Y0LCZjpkhlTdupAsdCYFOKY',
#   'description': 'Lexus IS 2008 Silver',
#   'amount': '3825000',
#   'region': 'Lagos State, Ogba',
#   'make': 'Lexus',
#   'model': 'IS',
#   'year_of_man': '2008',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '1313998.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'd5uvNr5uGBVtJLByjMCffV7X',
#   'description': 'Honda Accord 2008 Black',
#   'amount': '2812500',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2008',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '130260.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zjJUNonjVWrcM9mbZukMARBs',
#   'description': 'Toyota Highlander V6 2005 Gold',
#   'amount': '3250125',
#   'region': 'Anambra State, Onitsha',
#   'make': 'Toyota',
#   'model': 'Highlander',
#   'year_of_man': '2005',
#   'color': 'Gold',
#   'condition': 'Nigerian Used',
#   'mileage': '272192.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'V6',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '233.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'wk7w5HlcVtjdrF0yjxBlP4Ml',
#   'description': 'Toyota Corolla 2004 Red',
#   'amount': '2475000',
#   'region': 'Lagos State, Ajah',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2004',
#   'color': 'Red',
#   'condition': 'Nigerian Used',
#   'mileage': '463151.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'CiUM2IRsvXMHXcfqkiSb0oIu',
#   'description': 'Honda CR-V 2009 Green',
#   'amount': '2868750',
#   'region': 'Abuja (FCT), Katampe',
#   'make': 'Honda',
#   'model': 'CR-V',
#   'year_of_man': '2009',
#   'color': 'Green',
#   'condition': 'Nigerian Used',
#   'mileage': '160898.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '3lDx2zGflAhOstVF41Qf43uE',
#   'description': 'Lexus GS 2001 Brown',
#   'amount': '2250000',
#   'region': 'Abuja (FCT), Jabi',
#   'make': 'Lexus',
#   'model': 'GS',
#   'year_of_man': '2001',
#   'color': 'Brown',
#   'condition': 'Nigerian Used',
#   'mileage': '391443.0',
#   'engine_size': '3000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '1sM6W8Z2Cz6nm04fYNyT6n85',
#   'description': 'Mercedes-Benz GL-Class 2008 Black',
#   'amount': '3937500',
#   'region': 'Rivers State, Port-Harcourt',
#   'make': 'Mercedes-Benz',
#   'model': 'GL-Class',
#   'year_of_man': '2008',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '162309.0',
#   'engine_size': '4700.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'v8PMVm4IynLMkDD0Vx6gxDjc',
#   'description': 'Toyota Camry 2002 Silver',
#   'amount': '2328750',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2002',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '235152.0',
#   'engine_size': '2800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'XLE 4dr Sedan (2.4L 4cyl 4A)',
#   'drive_train': 'Front',
#   'reg_city': 'LAGOS',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '157.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '8D9vTLv4ohyFhfaDBl2mTEL5',
#   'description': 'Toyota Camry 2011 Gray',
#   'amount': '4162500',
#   'region': 'Abuja (FCT), Mararaba',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2011',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '282622.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Abuja',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'NTLnIDDcxuz9OR8GmVrFfxA',
#   'description': 'Toyota Camry 2007 Silver',
#   'amount': '4500000',
#   'region': 'Delta State, Oshimili South',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2007',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '187100.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'EDO',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'uRElNpV71fT2bWRzm3HkzSqE',
#   'description': 'Ford Edge 2007 Gray',
#   'amount': '2362500',
#   'region': 'Lagos State, Yaba',
#   'make': 'Ford',
#   'model': 'Edge',
#   'year_of_man': '2007',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '145218.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'AQtBUeD2uLTYPpqN8xaxqxDY',
#   'description': 'Toyota Camry 2003 Black',
#   'amount': '2587500',
#   'region': 'Lagos State, Alimosho',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2003',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '358128.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'A5iIAPe1KPv165R1y4lmAcqB',
#   'description': 'Honda Stream 2000 White',
#   'amount': '1125000',
#   'region': 'Kwara State, Ilorin East',
#   'make': 'Honda',
#   'model': 'Stream',
#   'year_of_man': '2000',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '498058.0',
#   'engine_size': '1600.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'Saloon',
#   'fuel_type': 'Petrol',
#   'transmission': 'Manual'},
#  {'car_id': 'dJ8KCIeybjA2i7qG42SBs0Bf',
#   'description': 'Nissan Altima 2009 Brown',
#   'amount': '2250000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Nissan',
#   'model': 'Altima',
#   'year_of_man': '2009',
#   'color': 'Brown',
#   'condition': 'Nigerian Used',
#   'mileage': '128532.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '5vLxkCq8P38f3iY9sOD5tqfn',
#   'description': 'Honda Accord 2007 Gold',
#   'amount': '2925000',
#   'region': 'Abuja (FCT), Garki 2',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2007',
#   'color': 'Gold',
#   'condition': 'Nigerian Used',
#   'mileage': '173223.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'q4iWav3wllMo4GcwHALnmqk9',
#   'description': 'Honda Pilot 2003 Gray',
#   'amount': '1960312',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Honda',
#   'model': 'Pilot',
#   'year_of_man': '2003',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '254557.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'mCzcz0BGkdnPhsNPdfmOCZwG',
#   'description': 'Chevrolet Suburban 2015 White',
#   'amount': '28125000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Chevrolet',
#   'model': 'Suburban',
#   'year_of_man': '2015',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '110363.0',
#   'engine_size': '5300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'rW6zBtgbIRgwhukQSjlFqva4',
#   'description': 'Nissan Pathfinder 2008 Black',
#   'amount': '3375000',
#   'region': 'Kwara State, Ilorin East',
#   'make': 'Nissan',
#   'model': 'Pathfinder',
#   'year_of_man': '2008',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '192676.0',
#   'engine_size': '4000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'cMALjcVYEZYpdJU2OgLfDWYE',
#   'description': 'Acura MDX 3.5L 4x4 2001 Gray',
#   'amount': '1912500',
#   'region': 'Lagos State, Ibeju',
#   'make': 'Acura',
#   'model': 'MDX',
#   'year_of_man': '2001',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '197857.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': '3.5L 4x4',
#   'drive_train': '4x4',
#   'reg_city': 'LAGOS',
#   'seat': '7',
#   'num_cylinder': '6.0',
#   'horse_power': '240.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'i7Ohwo1hjuAIVu0Ff1sGDTfy',
#   'description': 'Toyota Camry 2006 Gray',
#   'amount': '2295000',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2006',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '263180.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'hqICpAzvu7pWpeBLEh77vMYz',
#   'description': 'Toyota Corolla 2006 Gray',
#   'amount': '3150000',
#   'region': 'Lagos State, Ikoyi',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2006',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '244211.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'wwSHAuzpVezwkuOI6iPJTQQj',
#   'description': 'Subaru Outback H6 3.0  2001 Red',
#   'amount': '1350000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Subaru',
#   'model': 'Outback',
#   'year_of_man': '2001',
#   'color': 'Red',
#   'condition': 'Nigerian Used',
#   'mileage': '175127.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'H6 3.0',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'Hatchback',
#   'fuel_type': 'Petrol',
#   'transmission': 'Manual'},
#  {'car_id': 'gmjkw4p55QpdrI96qqhT1QVY',
#   'description': 'Toyota RAV4 2008 Red',
#   'amount': '3330000',
#   'region': 'Lagos State, Yaba',
#   'make': 'Toyota',
#   'model': 'RAV4',
#   'year_of_man': '2008',
#   'color': 'Red',
#   'condition': 'Nigerian Used',
#   'mileage': '135796.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'BrSGYoFDGqBYqVVs0gE2QYEC',
#   'description': 'Toyota Corolla 2003 Black',
#   'amount': '2475000',
#   'region': 'Abuja (FCT), Mararaba',
#   'make': 'Toyota',
#   'model': 'Corolla',
#   'year_of_man': '2003',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '482800.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS STATE',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '8TVQqvMkzupUggoWgS97Kvl',
#   'description': 'Mercedes-Benz E220 2002 Black',
#   'amount': '2250000',
#   'region': 'Abuja (FCT), Mararaba',
#   'make': 'Mercedes-Benz',
#   'model': 'E220',
#   'year_of_man': '2002',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '0.0',
#   'engine_size': '2000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Abuja',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '9RTA4jbLuInn2ZhNidEEnLEN',
#   'description': 'Toyota Camry 2010 Blue',
#   'amount': '3375000',
#   'region': 'Lagos State, Yaba',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2010',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '124257.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'anUHMzWakzLL6AJKBCiVBSoq',
#   'description': 'Lexus ES 2002 Silver',
#   'amount': '2047500',
#   'region': 'Lagos State, Lekki',
#   'make': 'Lexus',
#   'model': 'ES',
#   'year_of_man': '2002',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '344825.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'sfG2RCylukeZsor9K24eKOLd',
#   'description': 'Honda Accord 2008 Black',
#   'amount': '1976625',
#   'region': 'Lagos State, Surulere',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2008',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '165340.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'rAHBefxnwf4Tb5HQeDvJq1k1',
#   'description': 'Honda Accord Sedan EX 2004 Silver',
#   'amount': '1350000',
#   'region': 'Akwa Ibom State, Uyo',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2004',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '247904.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'Sedan EX',
#   'drive_train': 'Front Wheel',
#   'reg_city': 'ABUJA',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '0.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'prYNHdoB91QwIipPXEWAW7g1',
#   'description': 'Toyota Matrix 2004 Gray',
#   'amount': '2160000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Toyota',
#   'model': 'Matrix',
#   'year_of_man': '2004',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '129312.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '45XUtl0IUkBB3CFRfs0zDXc',
#   'description': 'Toyota Avalon 2006 Gold',
#   'amount': '2204998',
#   'region': 'Lagos State, Amuwo-Odofin',
#   'make': 'Toyota',
#   'model': 'Avalon',
#   'year_of_man': '2006',
#   'color': 'Gold',
#   'condition': 'Nigerian Used',
#   'mileage': '125415.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '5tvi79F5nesbtTnTRs4Drh96',
#   'description': 'Mercedes-Benz E350 2012 Blue',
#   'amount': '12375000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Mercedes-Benz',
#   'model': 'E350',
#   'year_of_man': '2012',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '132748.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'nNIWiT2FllLfQpvllnUTBUR7',
#   'description': 'Hyundai Sonata 2006 Silver',
#   'amount': '2925000',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Hyundai',
#   'model': 'Sonata',
#   'year_of_man': '2006',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '117841.0',
# ...
#   'year_of_man': '2009',
#   'color': 'Blue',
#   'condition': 'Nigerian Used',
#   'mileage': '93892.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'xhAoRdhScC39m4nw7sb36t2P',
#   'description': 'Mercedes-Benz GL-Class 2012 Gray',
#   'amount': '12480000',
#   'region': 'Abuja (FCT), Katampe',
#   'make': 'Mercedes-Benz',
#   'model': 'GL-Class',
#   'year_of_man': '2012',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '69524.0',
#   'engine_size': '4500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'dEuLfmt7t9ljDAc5iaz80H8W',
#   'description': 'Honda Odyssey 2016 Black',
#   'amount': '5250000',
#   'region': 'Rivers State, Port-Harcourt',
#   'make': 'Honda',
#   'model': 'Odyssey',
#   'year_of_man': '2016',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '61015.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Brand new',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'RIVERS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'dKLpx3QsszuQpa6KsuB6jw1i',
#   'description': 'Hyundai Ix35 2.0 CRDI 2012 Black',
#   'amount': '3213000',
#   'region': 'Lagos State, Ikeja',
#   'make': 'Hyundai',
#   'model': 'Ix35',
#   'year_of_man': '2012',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '93446.0',
#   'engine_size': '2000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Brand new',
#   'trim': '2.0 CRDI',
#   'drive_train': 'All Wheel',
#   'reg_city': 'LAGOS',
#   'seat': '5',
#   'num_cylinder': '4.0',
#   'horse_power': '135.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'Bqy8fS8Me2wAaoMRndG519gj',
#   'description': 'Mazda 626 2000 White',
#   'amount': '924000',
#   'region': 'Akwa Ibom State, Uyo',
#   'make': 'Mazda',
#   'model': '626',
#   'year_of_man': '2000',
#   'color': 'White',
#   'condition': 'Nigerian Used',
#   'mileage': '203790.0',
#   'engine_size': '2000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'ES 4dr Sedan (2.0L 4cyl 4A)',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '4.0',
#   'horse_power': '0.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'wLStFA0ibvM0ByUtZlTWERQl',
#   'description': 'Honda Accord 2008 Silver',
#   'amount': '2808000',
#   'region': 'Abuja (FCT), Mararaba',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2008',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '219911.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Abuja',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'kHhrLmFrmXzY8YdMS6QujNsH',
#   'description': 'Hyundai Santa Fe 2013 Brown',
#   'amount': '12480000',
#   'region': 'Lagos State, Kosofe',
#   'make': 'Hyundai',
#   'model': 'Santa Fe',
#   'year_of_man': '2013',
#   'color': 'Brown',
#   'condition': 'Foreign Used',
#   'mileage': '159702.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'lauRq88DHOa49RFoMaokv5hZ',
#   'description': 'Toyota Avalon Limited 2005 Silver',
#   'amount': '2912000',
#   'region': 'Abuja (FCT), Garki 2',
#   'make': 'Toyota',
#   'model': 'Avalon',
#   'year_of_man': '2005',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '471509.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'Limited',
#   'drive_train': 'Front Wheel',
#   'reg_city': 'unknown',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '280.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'nfBIBguylARUDQj9RtRp2ouV',
#   'description': 'Lexus RX 330 2005 White',
#   'amount': '7800000',
#   'region': 'Edo State, Benin City',
#   'make': 'Lexus',
#   'model': 'RX 330',
#   'year_of_man': '2005',
#   'color': 'White',
#   'condition': 'Foreign Used',
#   'mileage': '124427.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'BeSXyVx73RBT0SG2d2ndwKlf',
#   'description': 'Honda Accord Sedan EX V-6 2010 Gray',
#   'amount': '4011000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2010',
#   'color': 'Gray',
#   'condition': 'Foreign Used',
#   'mileage': '278563.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'Sedan EX V-6',
#   'drive_train': 'Front Wheel',
#   'reg_city': 'unknown',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '271.0',
#   'body_build': 'Sedan',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zF3mUeksaUzGT0ZWN21sye2z',
#   'description': 'Hyundai Santa Fe 2.7 V6 4WD 2009 Gray',
#   'amount': '3515200',
#   'region': 'Lagos State, Ikeja',
#   'make': 'Hyundai',
#   'model': 'Santa Fe',
#   'year_of_man': '2009',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '379604.0',
#   'engine_size': '3300.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': '2.7 V6 4WD',
#   'drive_train': 'All Wheel',
#   'reg_city': 'LAGOS',
#   'seat': '5',
#   'num_cylinder': '6.0',
#   'horse_power': '189.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'bbeZFEvI1DM9dQBR41z27asp',
#   'description': 'Toyota Sequoia 2003 Black',
#   'amount': '2496000',
#   'region': 'Lagos State, Ikoyi',
#   'make': 'Toyota',
#   'model': 'Sequoia',
#   'year_of_man': '2003',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '137914.0',
#   'engine_size': '4700.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'l84q94wfmBuWPBnDZVrQiMUA',
#   'description': 'Honda Ridgeline 2006 Silver',
#   'amount': '3640000',
#   'region': 'Lagos State, Ojodu',
#   'make': 'Honda',
#   'model': 'Ridgeline',
#   'year_of_man': '2006',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '355604.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'Pick-up Double Cabin',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'dUPVESEOF7jyRjb2KSnXKfRM',
#   'description': 'Toyota Camry 2003 Black',
#   'amount': '1653750',
#   'region': 'Lagos State, Surulere',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2003',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '214455.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'cPNyfSLiBX8fLARlhDhOzZxY',
#   'description': 'Toyota Sienna 2002 Silver',
#   'amount': '1470000',
#   'region': 'Ogun State, Ado-Odo/Ota',
#   'make': 'Toyota',
#   'model': 'Sienna',
#   'year_of_man': '2002',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '289061.0',
#   'engine_size': '3000.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'rNDbYhtTdnaXIBc4vLpllmU1',
#   'description': 'Honda Pilot 2006 Purple',
#   'amount': '2100000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Honda',
#   'model': 'Pilot',
#   'year_of_man': '2006',
#   'color': 'Purple',
#   'condition': 'Nigerian Used',
#   'mileage': '175823.0',
#   'engine_size': '3500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'zrp7tMufDHk4qoWKzfM8C9Pl',
#   'description': 'Acura RDX 2008 White',
#   'amount': '4462500',
#   'region': 'Lagos State, Mushin',
#   'make': 'Acura',
#   'model': 'RDX',
#   'year_of_man': '2008',
#   'color': 'White',
#   'condition': 'Foreign Used',
#   'mileage': '252420.0',
#   'engine_size': '2300.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'bqocaOe8Qsc6xlVOYLnnN8ir',
#   'description': 'Mercedes-Benz S-Class S 550 2008 Gray',
#   'amount': '7875000',
#   'region': 'Lagos State, Lekki',
#   'make': 'Mercedes-Benz',
#   'model': 'S-Class',
#   'year_of_man': '2008',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '71290.0',
#   'engine_size': '5500.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'S 550',
#   'drive_train': 'unknown',
#   'reg_city': 'Ibadan',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'u01BwjT543Sm8OHzI59iVxt',
#   'description': 'Honda Accord 2003 Silver',
#   'amount': '1772000',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2003',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '321729.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'kz6HUf7AP695aITYMXMRftVD',
#   'description': 'Audi A3 1999 Silver',
#   'amount': '840000',
#   'region': 'Abuja (FCT), Gwarinpa',
#   'make': 'Audi',
#   'model': 'A3',
#   'year_of_man': '1999',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '293267.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Manual'},
#  {'car_id': 'pTLkjdrrzXWAP34xK0cx2Ksc',
#   'description': 'Hyundai Creta 2018 Silver',
#   'amount': '6930000',
#   'region': 'Lagos State, Magodo',
#   'make': 'Hyundai',
#   'model': 'Creta',
#   'year_of_man': '2018',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '63137.0',
#   'engine_size': '1600.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Brand new',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'SUV',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'uE9SgDInnG0ARaA2WMQuJVjU',
#   'description': 'Honda Accord 2007 Gray',
#   'amount': '1365000',
#   'region': 'Abuja (FCT), Lugbe District',
#   'make': 'Honda',
#   'model': 'Accord',
#   'year_of_man': '2007',
#   'color': 'Gray',
#   'condition': 'Nigerian Used',
#   'mileage': '287526.0',
#   'engine_size': '2400.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'LAGOS',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'ucpo2upCKymadi0xz5yrUbX',
#   'description': 'Toyota Camry 2010 Silver',
#   'amount': '5824000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Toyota',
#   'model': 'Camry',
#   'year_of_man': '2010',
#   'color': 'Silver',
#   'condition': 'Foreign Used',
#   'mileage': '258736.0',
#   'engine_size': '2500.0',
#   'selling_cond': 'Imported',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'unknown',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': '2CI7n0heZVvlVBsRxwhd4gT0',
#   'description': 'Opel Zafira 2005 Silver',
#   'amount': '2520000',
#   'region': 'Oyo State, Ibadan',
#   'make': 'Opel',
#   'model': 'Zafira',
#   'year_of_man': '2005',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '176791.0',
#   'engine_size': '2200.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  {'car_id': 'iTjF4QBa6rMJB8wGYCBNzXSI',
#   'description': 'Peugeot 307 2005 Silver',
#   'amount': '1560000',
#   'region': 'Lagos State, Ikorodu',
#   'make': 'Peugeot',
#   'model': '307',
#   'year_of_man': '2005',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '175231.0',
#   'engine_size': '1600.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Manual'},
#  {'car_id': '345hBYfbEOHbsqrUbVHu8Nwg',
#   'description': 'Mercedes-Benz C180 2000 Black',
#   'amount': '1575000',
#   'region': 'Oyo State, Ibadan',
#   'make': 'Mercedes-Benz',
#   'model': 'C180',
#   'year_of_man': '2000',
#   'color': 'Black',
#   'condition': 'Nigerian Used',
#   'mileage': '163267.0',
#   'engine_size': '1800.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Registered',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'Lagos',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Manual'},
#  {'car_id': 'pToXrzhlwdMWWy8OjCZ8SxSx',
#   'description': 'Toyota Avensis 2005 Silver',
#   'amount': '1680000',
#   'region': 'Lagos State, Amuwo-Odofin',
#   'make': 'Toyota',
#   'model': 'Avensis',
#   'year_of_man': '2005',
#   'color': 'Silver',
#   'condition': 'Nigerian Used',
#   'mileage': '193330.0',
#   'engine_size': '0.0',
#   'selling_cond': 'Registered',
#   'bought_cond': 'Imported',
#   'trim': 'unknown',
#   'drive_train': 'unknown',
#   'reg_city': 'ABUJA',
#   'seat': '0',
#   'num_cylinder': '0.0',
#   'horse_power': '0.0',
#   'body_build': 'unknown',
#   'fuel_type': 'Petrol',
#   'transmission': 'Automatic'},
#  ...]

# %%
from sqlalchemy.orm import Session

def clean_and_cast(record):
    """Convert numeric strings to int while preserving 'unknown' values."""
    def to_int_or_unknown(value):
        # Keep 'unknown' literal as-is
        if value in ("", None):
            return None
        if str(value).lower() == "unknown":
            return "unknown"
        try:
            # Convert "272474.0" → 272474
            return int(float(value))
        except ValueError:
            return "unknown"

    # Numeric fields (cast or preserve 'unknown')
    record["amount"] = to_int_or_unknown(record.get("amount"))
    record["year_of_man"] = to_int_or_unknown(record.get("year_of_man"))
    record["mileage"] = to_int_or_unknown(record.get("mileage"))
    record["engine_size"] = to_int_or_unknown(record.get("engine_size"))
    record["num_cylinder"] = to_int_or_unknown(record.get("num_cylinder"))
    record["horse_power"] = to_int_or_unknown(record.get("horse_power"))

    # Leave other text fields untouched — they already have 'unknown'
    return record


with Session(engine) as sess:
    sess.bulk_save_objects([Cars45(**clean_and_cast(record)) for record in store])
    sess.commit()
# Out:
# 2025-10-04 11:12:47,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-04 11:12:47,455 INFO sqlalchemy.engine.Engine INSERT INTO cars45 (car_id, description, amount, region, make, model, year_of_man, color, condition, mileage, engine_size, selling_cond, bought_cond, trim, drive_train, reg_city, seat, num_cylinder, horse_power, body_build, fuel_type, transmission) V ... 426484 characters truncated ... linder__999)s, %(horse_power__999)s, %(body_build__999)s, %(fuel_type__999)s, %(transmission__999)s)
# 2025-10-04 11:12:47,456 INFO sqlalchemy.engine.Engine [cached since 755.8s ago (insertmanyvalues) 1/3 (unordered)] {'selling_cond__0': 'Imported', 'fuel_type__0': 'Petrol', 'bought_cond__0': 'Imported', 'reg_city__0': 'unknown', 'engine_size__0': 3500, 'seat__0': '5', 'body_build__0': 'Sedan', 'mileage__0': 272474, 'model__0': 'ES', 'year_of_man__0': 2013, 'num_cylinder__0': 6, 'car_id__0': '5IQTDBTYmvK1tJwhdvGJfESJ', 'condition__0': 'Foreign Used', 'color__0': 'Red', 'description__0': 'Lexus ES 350 FWD 2013 Red', 'make__0': 'Lexus', 'trim__0': '350 FWD', 'horse_power__0': 268, 'amount__0': 12937500, 'drive_train__0': 'Front Wheel', 'region__0': 'Lagos State, Ikeja', 'transmission__0': 'Automatic', 'selling_cond__1': 'Registered', 'fuel_type__1': 'Petrol', 'bought_cond__1': 'Registered', 'reg_city__1': 'unknown', 'engine_size__1': 5000, 'seat__1': '0', 'body_build__1': 'SUV', 'mileage__1': 102281, 'model__1': 'Range Rover', 'year_of_man__1': 2012, 'num_cylinder__1': 0, 'car_id__1': 'zpZUGomoVXuKk9UFa8j8moC9', 'condition__1': 'Nigerian Used', 'color__1': 'White', 'description__1': 'Land Rover Range Rover 2012 White', 'make__1': 'Land Rover', 'trim__1': 'unknown', 'horse_power__1': 0, 'amount__1': 6750000, 'drive_train__1': 'unknown', 'region__1': 'Abuja (FCT), Garki 2', 'transmission__1': 'Automatic', 'selling_cond__2': 'Imported', 'fuel_type__2': 'Petrol', 'bought_cond__2': 'Imported', 'reg_city__2': 'unknown', 'engine_size__2': 5700, 'seat__2': '0' ... 21900 parameters truncated ... 'trim__997': 'unknown', 'horse_power__997': 0, 'amount__997': 1560000, 'drive_train__997': 'unknown', 'region__997': 'Lagos State, Ikorodu', 'transmission__997': 'Manual', 'selling_cond__998': 'Registered', 'fuel_type__998': 'Petrol', 'bought_cond__998': 'Registered', 'reg_city__998': 'Lagos', 'engine_size__998': 1800, 'seat__998': '0', 'body_build__998': 'unknown', 'mileage__998': 163267, 'model__998': 'C180', 'year_of_man__998': 2000, 'num_cylinder__998': 0, 'car_id__998': '345hBYfbEOHbsqrUbVHu8Nwg', 'condition__998': 'Nigerian Used', 'color__998': 'Black', 'description__998': 'Mercedes-Benz C180 2000 Black', 'make__998': 'Mercedes-Benz', 'trim__998': 'unknown', 'horse_power__998': 0, 'amount__998': 1575000, 'drive_train__998': 'unknown', 'region__998': 'Oyo State, Ibadan', 'transmission__998': 'Manual', 'selling_cond__999': 'Registered', 'fuel_type__999': 'Petrol', 'bought_cond__999': 'Imported', 'reg_city__999': 'ABUJA', 'engine_size__999': 0, 'seat__999': '0', 'body_build__999': 'unknown', 'mileage__999': 193330, 'model__999': 'Avensis', 'year_of_man__999': 2005, 'num_cylinder__999': 0, 'car_id__999': 'pToXrzhlwdMWWy8OjCZ8SxSx', 'condition__999': 'Nigerian Used', 'color__999': 'Silver', 'description__999': 'Toyota Avensis 2005 Silver', 'make__999': 'Toyota', 'trim__999': 'unknown', 'horse_power__999': 0, 'amount__999': 1680000, 'drive_train__999': 'unknown', 'region__999': 'Lagos State, Amuwo-Odofin', 'transmission__999': 'Automatic'}
# 2025-10-04 11:12:47,600 INFO sqlalchemy.engine.Engine INSERT INTO cars45 (car_id, description, amount, region, make, model, year_of_man, color, condition, mileage, engine_size, selling_cond, bought_cond, trim, drive_train, reg_city, seat, num_cylinder, horse_power, body_build, fuel_type, transmission) V ... 426484 characters truncated ... linder__999)s, %(horse_power__999)s, %(body_build__999)s, %(fuel_type__999)s, %(transmission__999)s)
# 2025-10-04 11:12:47,601 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (unordered)] {'selling_cond__0': 'Registered', 'fuel_type__0': 'Petrol', 'bought_cond__0': 'Imported', 'reg_city__0': 'Lagos', 'engine_size__0': 2500, 'seat__0': '0', 'body_build__0': 'unknown', 'mileage__0': 198626, 'model__0': 'Camry', 'year_of_man__0': 2010, 'num_cylinder__0': 0, 'car_id__0': 'vXyZAtcOk3pynP3cvvRHe8iI', 'condition__0': 'Nigerian Used', 'color__0': 'Black', 'description__0': 'Toyota Camry 2010 Black', 'make__0': 'Toyota', 'trim__0': 'unknown', 'horse_power__0': 0, 'amount__0': 3045000, 'drive_train__0': 'unknown', 'region__0': 'Oyo State, Ibadan', 'transmission__0': 'Automatic', 'selling_cond__1': 'Registered', 'fuel_type__1': 'Petrol', 'bought_cond__1': 'Registered', 'reg_city__1': 'unknown', 'engine_size__1': 3000, 'seat__1': '0', 'body_build__1': 'unknown', 'mileage__1': 276565, 'model__1': 'C300', 'year_of_man__1': 2008, 'num_cylinder__1': 0, 'car_id__1': 'wOXuhGohHLxVObM3RNwzOMGV', 'condition__1': 'Nigerian Used', 'color__1': 'Red', 'description__1': 'Mercedes-Benz C300 2008 Red', 'make__1': 'Mercedes-Benz', 'trim__1': 'unknown', 'horse_power__1': 0, 'amount__1': 3570000, 'drive_train__1': 'unknown', 'region__1': 'Abuja (FCT), Garki 2', 'transmission__1': 'Automatic', 'selling_cond__2': 'Registered', 'fuel_type__2': 'Petrol', 'bought_cond__2': 'Imported', 'reg_city__2': 'LAGOS', 'engine_size__2': 3700, 'seat__2': '7' ... 21900 parameters truncated ... 'trim__997': 'unknown', 'horse_power__997': 0, 'amount__997': 1575000, 'drive_train__997': 'unknown', 'region__997': 'Oyo State, Ibadan', 'transmission__997': 'Automatic', 'selling_cond__998': 'Registered', 'fuel_type__998': 'Petrol', 'bought_cond__998': 'Registered', 'reg_city__998': 'KOGI STATE', 'engine_size__998': 2400, 'seat__998': '0', 'body_build__998': 'SUV', 'mileage__998': 195556, 'model__998': 'RAV4', 'year_of_man__998': 2003, 'num_cylinder__998': 0, 'car_id__998': '53p6cLa3SHFnToYuomlcgs1A', 'condition__998': 'Nigerian Used', 'color__998': 'Silver', 'description__998': 'Toyota RAV4 2003 Silver', 'make__998': 'Toyota', 'trim__998': 'unknown', 'horse_power__998': 0, 'amount__998': 1785000, 'drive_train__998': 'unknown', 'region__998': 'Abuja (FCT), Mararaba', 'transmission__998': 'Automatic', 'selling_cond__999': 'Imported', 'fuel_type__999': 'Petrol', 'bought_cond__999': 'Imported', 'reg_city__999': 'unknown', 'engine_size__999': 3300, 'seat__999': '7', 'body_build__999': 'SUV', 'mileage__999': 188745, 'model__999': 'Sienna', 'year_of_man__999': 2005, 'num_cylinder__999': 6, 'car_id__999': 'saQyV6gDao7n7fp4oLcHBgX3', 'condition__999': 'Foreign Used', 'color__999': 'Gray', 'description__999': 'Toyota Sienna LE AWD 2005 Gray', 'make__999': 'Toyota', 'trim__999': 'LE AWD', 'horse_power__999': 233, 'amount__999': 4252500, 'drive_train__999': 'All Wheel', 'region__999': 'Anambra State, Onitsha', 'transmission__999': 'Automatic'}
# 2025-10-04 11:12:47,746 INFO sqlalchemy.engine.Engine INSERT INTO cars45 (car_id, description, amount, region, make, model, year_of_man, color, condition, mileage, engine_size, selling_cond, bought_cond, trim, drive_train, reg_city, seat, num_cylinder, horse_power, body_build, fuel_type, transmission) V ... 381010 characters truncated ... linder__893)s, %(horse_power__893)s, %(body_build__893)s, %(fuel_type__893)s, %(transmission__893)s)
# 2025-10-04 11:12:47,747 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (unordered)] {'selling_cond__0': 'Registered', 'fuel_type__0': 'Petrol', 'bought_cond__0': 'Registered', 'reg_city__0': 'unknown', 'engine_size__0': 2000, 'seat__0': '0', 'body_build__0': 'SUV', 'mileage__0': 234312, 'model__0': 'Sportage', 'year_of_man__0': 2002, 'num_cylinder__0': 0, 'car_id__0': '69fZ1eJnwqniAs1q5KpNfDXH', 'condition__0': 'Nigerian Used', 'color__0': 'Black', 'description__0': 'Kia Sportage 2002 Black', 'make__0': 'Kia', 'trim__0': 'unknown', 'horse_power__0': 0, 'amount__0': 1470000, 'drive_train__0': 'unknown', 'region__0': 'Oyo State, Ibadan', 'transmission__0': 'Automatic', 'selling_cond__1': 'Registered', 'fuel_type__1': 'Petrol', 'bought_cond__1': 'Imported', 'reg_city__1': 'unknown', 'engine_size__1': 4000, 'seat__1': '0', 'body_build__1': 'SUV', 'mileage__1': 135908, 'model__1': '4-Runner', 'year_of_man__1': 2008, 'num_cylinder__1': 0, 'car_id__1': 'a58np6UFhYz42KEqTo1LDZu7', 'condition__1': 'Nigerian Used', 'color__1': 'Black', 'description__1': 'Toyota 4-Runner 2008 Black', 'make__1': 'Toyota', 'trim__1': 'unknown', 'horse_power__1': 0, 'amount__1': 2735000, 'drive_train__1': 'unknown', 'region__1': 'Kwara State, Ilorin East', 'transmission__1': 'Automatic', 'selling_cond__2': 'Registered', 'fuel_type__2': 'Petrol', 'bought_cond__2': 'Registered', 'reg_city__2': 'LAGOS', 'engine_size__2': 2700, 'seat__2': '5' ... 19568 parameters truncated ... 'trim__891': 'unknown', 'horse_power__891': 0, 'amount__891': 4725000, 'drive_train__891': 'unknown', 'region__891': 'Lagos State, Lekki', 'transmission__891': 'Automatic', 'selling_cond__892': 'Imported', 'fuel_type__892': 'Petrol', 'bought_cond__892': 'Imported', 'reg_city__892': 'unknown', 'engine_size__892': 4200, 'seat__892': '0', 'body_build__892': 'SUV', 'mileage__892': 298187, 'model__892': 'Range Rover Sport', 'year_of_man__892': 2008, 'num_cylinder__892': 0, 'car_id__892': 'CzI81oX5BIFITuoFozBtnQLS', 'condition__892': 'Foreign Used', 'color__892': 'White', 'description__892': 'Land Rover Range Rover Sport 2008 White', 'make__892': 'Land Rover', 'trim__892': 'unknown', 'horse_power__892': 0, 'amount__892': 6930000, 'drive_train__892': 'unknown', 'region__892': 'Edo State, Benin City', 'transmission__892': 'Automatic', 'selling_cond__893': 'Registered', 'fuel_type__893': 'Petrol', 'bought_cond__893': 'Imported', 'reg_city__893': 'ABUJA', 'engine_size__893': 1800, 'seat__893': '5', 'body_build__893': 'Sedan', 'mileage__893': 289222, 'model__893': 'Corolla', 'year_of_man__893': 2005, 'num_cylinder__893': 4, 'car_id__893': '41KZsjPRmovhziJJQ3gkw37Q', 'condition__893': 'Nigerian Used', 'color__893': 'White', 'description__893': 'Toyota Corolla Sedan 2005 White', 'make__893': 'Toyota', 'trim__893': 'Sedan', 'horse_power__893': 90, 'amount__893': 2600000, 'drive_train__893': 'Front', 'region__893': 'Abuja (FCT), Lugbe District', 'transmission__893': 'Automatic'}
# 2025-10-04 11:12:47,854 INFO sqlalchemy.engine.Engine COMMIT
